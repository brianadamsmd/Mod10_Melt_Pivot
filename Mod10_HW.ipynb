# %%
import pandas as pd
import numpy as np

# Set display options for better console output
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# Load the dataframe
df = pd.read_csv('cardio_train.csv', delimiter=';')

print("--- Successfully loaded cardio_train.csv ---")
print(f"Original DataFrame shape: {df.shape}\n")
print("Original DataFrame head:")
print(df.head())
print("\n" + "="*80 + "\n")

# Made 'gender' more readable (1: Female, 2: Male)

df['gender'] = df['gender'].map({1: 'Female', 2: 'Male'})
sample_df = df[['id', 'age', 'gender', 'ap_hi', 'ap_lo']]

print("--- Created a narrower sample for Melt/Pivot demo ---")
print(sample_df.head(10))
print("\n" + "="*80 + "\n")

# 1. Melt
# 'melt' is used to transform a DataFrame from a wide format to a long format.
# It "unpivots" the data.
# Here, we keep 'id', 'age', and 'gender' as identifier variables.
# We unpivot 'ap_hi' (systolic) and 'ap_lo' (diastolic) into two new columns:
# 'pressure_type' (which will contain 'ap_hi' or 'ap_lo')
# 'pressure_value' (which will contain the corresponding value)

print("--- 1. DEMONSTRATING melt() ---")
melted_df = sample_df.melt(
    id_vars=['id', 'age', 'gender'],
    value_vars=['ap_hi', 'ap_lo'],
    var_name='pressure_type',
    value_name='pressure_value'
)
print("Melted DataFrame (long format):")
print(melted_df)
print("\n" + "="*80 + "\n")


# 2. Pivot
# 'pivot' is the opposite of 'melt'. It transforms from a long format to a wide format.
# We can use it to restore our 'melted_df' back to its original(ish) structure.
# - index: The column(s) to use as the new DataFrame's index.
# - columns: The column to use to create the new DataFrame's columns.
# - values: The column to use for populating the new DataFrame's values.

print("--- 2. DEMONSTRATING pivot() ---")
pivoted_df = melted_df.pivot(
    index=['id', 'age', 'gender'],
    columns='pressure_type',
    values='pressure_value'
)
# .reset_index() is used to turn the index columns back into regular columns
pivoted_df = pivoted_df.reset_index().rename_axis(None, axis=1) 

print("Pivoted DataFrame (wide format, restored from melt):")
print(pivoted_df)
print("\n" + "="*80 + "\n")


# 3. Groupby
# 'groupby' is used for splitting the data into groups based on some criteria.
# It creates a 'DataFrameGroupBy' object. This step *by itself* doesn't
# compute anything, it just sets up the groups.
# Let's use the full 'df' for this.

print("--- 3. DEMONSTRATING groupby() ---")
# Let's group by 'gender' (1=Female, 2=Male) and 'cholesterol' (1, 2, 3)
grouped_data = df.groupby(['gender', 'cholesterol'])

print(f"Created a DataFrameGroupBy object: {type(grouped_data)}")
print("Groups found (first 5):")
print(list(grouped_data.groups.keys())[:5])

# A common operation is to get the size of each group
print("\nSize of each group (gender, cholesterol):")
print(grouped_data.size())
print("\n" + "="*80 + "\n")


# 4. Aggregation (agg)
# 'agg' is typically used *after* a 'groupby' to perform one or more
# calculations on the grouped data.
# We can apply different functions to different columns.

print("--- 4. DEMONSTRATING Aggregation (.agg()) ---")
# Let's use our 'grouped_data' from the previous step.
# We will calculate:
# - The mean 'weight' and 'height'
# - The median 'ap_hi' (systolic pressure)
# - The total count of smokers ('smoke' column, where 1=smoker)

aggregations = {
    'weight': 'mean',
    'height': 'mean',
    'ap_hi': 'median',
    'smoke': 'sum'  # This gives the total number of smokers in the group
}

# We can also use NumPy functions
# 'weight': [np.mean, np.std]  <- This would give mean and std dev

aggregated_df = grouped_data.agg(aggregations)

# Let's round the results for cleaner output
aggregated_df = aggregated_df.round(2)

print("Aggregated results (mean weight/height, median ap_hi, total smokers):")
print(aggregated_df)
print("\n" + "="*80 + "\n")


# 5. Iteration (iterrows)
# 'iterrows' iterates over DataFrame rows as (index, Series) pairs.
#
# *** WARNING: ***
# Iterating over a DataFrame is almost always the wrong approach.
# It is VERY SLOW and inefficient compared to vectorized operations
# (e.g., df['new_col'] = df['col_a'] + df['col_b']).
# This is only for demonstration or when you have a complex function
# that *cannot* be vectorized.

print("--- 5. DEMONSTRATING Iteration (.iterrows()) ---")
print("Iterating over the *first 5 rows* of the main DataFrame:")

# We use .head(5) to only iterate over a tiny sample.
# NEVER do this on the full 'df' if you can avoid it.
for index, row in df.head(5).iterrows():
    print(f"\nRow Index: {index}")
    print(f"  ID: {row['id']}")
    print(f"  Age (days): {row['age']}")
    print(f"  Weight: {row['weight']}")
    print(f"  Cardio risk (1=yes): {row['cardio']}")

print("\n--- Demonstration Complete ---")
# Out:
# --- Successfully loaded cardio_train.csv ---
# Original DataFrame shape: (69301, 13)
#
# Original DataFrame head:
#     id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  cardio
# 0  988  22469       1     155    69.0    130     80            2     2      0     0       1       0
# 1  989  14648       1     163    71.0    110     70            1     1      0     0       1       1
# 2  990  21901       1     165    70.0    120     80            1     1      0     0       1       0
# 3  991  14549       2     165    85.0    120     80            1     1      1     1       1       0
# 4  992  23393       1     155    62.0    120     80            1     1      0     0       1       0
#
# ...
#
# --- Created a narrower sample for Melt/Pivot demo ---
#      id    age  gender  ap_hi  ap_lo
# 0   988  22469  Female    130     80
# 1   989  14648  Female    110     70
# 2   990  21901  Female    120     80
# 3   991  14549    Male    120     80
# ...
